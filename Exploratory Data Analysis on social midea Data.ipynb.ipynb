# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("sentimentdataset_1.csv")

# %%
print(df.head())
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text Sentiment  \
# 727  Collaborating on a science project that receiv...    Happy
# 728  Attending a surprise birthday party organized ...    Happy
# 729  Successfully fundraising for a school charity ...    Happy
# 730  Participating in a multicultural festival, cel...    Happy
# 731  Organizing a virtual talent show during challe...    Happy
#
#                Timestamp                                   User     Platform  \
# 727  2017-08-18 18:20:00       ScienceProjectSuccessHighSchool     Facebook
# 728  2018-06-22 14:15:00            BirthdayPartyJoyHighSchool    Instagram
# 729  2019-04-05 17:30:00   CharityFundraisingTriumphHighSchool      Twitter
# 730  2020-02-29 20:45:00    MulticulturalFestivalJoyHighSchool     Facebook
# ...

# %%
df.shape
# Out:
# (732, 15)

# %%
df.dtypes
# Out:
# Unnamed: 0.1      int64
# Unnamed: 0        int64
# Text             object
# Sentiment        object
# Timestamp        object
# User             object
# Platform         object
# Hashtags         object
# Retweets        float64
# Likes           float64
# Country          object
# Year              int64
# Month             int64
# Day               int64
# Hour              int64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %%
(df.isnull().sum())/(df.shape[0]*df.shape[1]*100)
# Out:
# Unnamed: 0.1    0.0
# Unnamed: 0      0.0
# Text            0.0
# Sentiment       0.0
# Timestamp       0.0
# User            0.0
# Platform        0.0
# Hashtags        0.0
# Retweets        0.0
# Likes           0.0
# Country         0.0
# Year            0.0
# Month           0.0
# Day             0.0
# Hour            0.0
# dtype: float64

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# Unnamed: 0.1    0.0
# Unnamed: 0      0.0
# Text            0.0
# Sentiment       0.0
# Timestamp       0.0
# User            0.0
# Platform        0.0
# Hashtags        0.0
# Retweets        0.0
# Likes           0.0
# Country         0.0
# Year            0.0
# Month           0.0
# Day             0.0
# Hour            0.0
# dtype: float64

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Text', 'Sentiment', 'Timestamp', 'User',
#        'Platform', 'Hashtags', 'Retweets', 'Likes', 'Country', 'Year', 'Month',
#        'Day', 'Hour'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
df.select_dtypes(include=['int64', 'float64']).boxplot(figsize=(10, 6))
plt.xticks(rotation=90)
plt.show()

# %%
df.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %%
df.describe(include='object')
# Out:
#                                                      Text    Sentiment  \
# count                                                 732          732
# unique                                                707          279
# top      A compassionate rain, tears of empathy fallin...   Positive
# freq                                                    3           44
#
#                   Timestamp             User     Platform  \
# count                   732              732          732
# unique                  683              685            4
# top     2022-07-17 06:15:00   WindWhisperer    Instagram
# freq                      3                3          258
#
#                                 Hashtags Country
# count                                732     732
# unique                               697     115
# top      #Compassionate #TearsOfEmpathy      USA
# freq                                   3      59

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df.select_dtypes(include=['int64', 'float64']).corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
sns.histplot(df['Platform'])
plt.show()

# %%
sns.countplot(x = df['Hour'],palette=['blue', 'red', 'yellow'])
plt.legend(title="Hour", labels=df['Hour'].unique())
plt.show()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_31572\628444922.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = df['Hour'],palette=['blue', 'red', 'yellow'])
# C:\Users\shiva\AppData\Local\Temp\ipykernel_31572\628444922.py:1: UserWarning:
# The palette list has fewer values (3) than needed (22) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x = df['Hour'],palette=['blue', 'red', 'yellow'])

# %%
plt.pie(df['Sentiment'].value_counts(),startangle=90,counterclock=False,wedgeprops={'edgecolor':'black'})
plt.title("Platform")

plt.show()

# %%
plt.bar(df['Platform'], df['Retweets'])  
plt.xlabel('Hashtags')
plt.ylabel('Country')
plt.title('Hour')
plt.xticks(rotation=45) 
plt.show()

# %%
plt.bar(df['Platform'], df['Retweets'])  
plt.xlabel('Status Mode')
plt.ylabel('Retweets')
plt.title('Hour')
plt.xticks(rotation=45) 
plt.show()

# %%
yearly_sales = df.groupby('Year')['Hour'].sum().reset_index()
sns.lineplot(x=yearly_sales['Year'], y=yearly_sales['Hour'], marker='o', color='blue')
plt.xlabel('Year')
plt.xticks(rotation=90)
plt.ylabel('Day')
plt.title('Month')
plt.show()

# %%
status_quantity = df.groupby('Platform')['Hour'].sum()
plt.bar(status_quantity.index, status_quantity.values)
plt.xlabel('Country')
plt.ylabel('month')
plt.title('Sentiment')
plt.xticks(rotation=45) 
plt.show()

# %%
status_dealsize_sales = df.groupby(['Platform', 'Year'])['Month'].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='Platform', y='Month', hue='Year', data=status_dealsize_sales, palette=['blue','red','orange'])

plt.xlabel('Country')
plt.ylabel('Day')
plt.title('Retweets')
plt.xticks(rotation=45)
plt.legend(title='likes')
plt.show()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_31572\1783447374.py:3: UserWarning:
# The palette list has fewer values (3) than needed (14) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='Platform', y='Month', hue='Year', data=status_dealsize_sales, palette=['blue','red','orange'])

# %%
status_dealsize_QuantityOrder = df.groupby(['Platform', 'Year'])['Hour'].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='Platform', y='Hour', hue='Year', data=status_dealsize_QuantityOrder, palette=['pink','yellow','skyblue'])

plt.xlabel('Country')
plt.ylabel('Year')
plt.title('Retweets')
plt.xticks(rotation=45)
plt.legend(title='Likes')
plt.show()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_31572\515040634.py:3: UserWarning:
# The palette list has fewer values (3) than needed (14) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='Platform', y='Hour', hue='Year', data=status_dealsize_QuantityOrder, palette=['pink','yellow','skyblue'])

# %%
top_states = df.groupby('Country')['Year'].sum().nlargest(10).reset_index()
plt.figure(figsize=(12, 6))
sns.barplot(x='Country', y='Year', data=top_states, palette='viridis')

plt.xlabel('Country')
plt.ylabel('Year')
plt.title('Top 10 Countries with Highest User')
plt.xticks(rotation=45)  
plt.show()
# Out:
# C:\Users\shiva\AppData\Local\Temp\ipykernel_31572\3433300472.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Country', y='Year', data=top_states, palette='viridis')

# %%
top_countries = df.groupby('Country')['Hour'].sum().nlargest(10)

plt.figure(figsize=(12, 6))
plt.bar(top_countries.index, top_countries.values, color='royalblue')

plt.xlabel('Country')
plt.ylabel('Month')
plt.title('Top 10 Countries with Highest Hashtags')
plt.xticks(rotation=45)  

plt.show()

# %%
df.groupby('Year')['Country'].sum().plot(kind='pie',autopct='%1.1f%%', title="Sales Distribution by Territory Region")
plt.ylabel('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df.groupby('Year')['Country'].sum().plot(kind='pie',autopct='%1.1f%%', title="Sales Distribution by Territory Region")
#       2 plt.ylabel('')
#       3 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:70, in plot(data, kind, **kwargs)
#      68             ax = plt.gca()
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      71 plot_obj.generate()
#      72 plot_obj.draw()
#
# ...
